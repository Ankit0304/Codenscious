# %% [markdown]
# que1 :Count Vowels

# %%
String = "heytherehowwhenwhere"
vowels = 'aeiou'
String = String.lower()
count = 0
for i in String:
    if i in vowels:
        count += 1
    
print(count)
# Out:
# 7
