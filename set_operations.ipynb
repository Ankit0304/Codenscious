# %% [markdown]
# Basic Operations

# %%
fruits = {'apple', 'banana', 'mango', 'grapes','lichi'}
fruits.add('gavava')
print("after adding", fruits)
fruits.remove('lichi')
fruits.discard('strawberry')
