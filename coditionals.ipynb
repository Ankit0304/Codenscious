# %% [markdown]
# que1 : Even or odd check

# %%
num = int(input())
if num%2==0:
    print('Even')
else:
    print('Odd')

# %% [markdown]
# que2 : check a leap year

# %%
year = int(input("Enter a year: "))
if year % 100 == 0:
    if year % 400 == 0:
        print(f'{year} is a leap year')
    else:
        print(f'{year} is not a leap year')
else:
    if year % 4 == 0:
        print(f'{year} is a leap year')
    else:
        print(f'{year} is not a leap year')
# Out:
# 2014 is not a leap year
